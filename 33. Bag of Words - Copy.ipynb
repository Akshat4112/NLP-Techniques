# %%
from nltk.corpus import stopwords
import string
import re
from collections import Counter

# %%
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# %%
from os import listdir

def process_docs(directory):
    for filename in listdir(directory):
        if not filename.endswith(".txt"):
            next
        path = directory + '/' + filename
        doc = load_doc(path)
        print('Loaded %s' % filename)

# %%
def clean_doc(text):
    tokens = text.split()
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    tokens = [word for word in tokens if len(word) > 1]
    return tokens

# %%
def add_doc_to_vocab(filename, vocab):
    doc = load_doc(filename)
    tokens = clean_doc(doc)
    vocab.update(tokens)

# %%
def save_list(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
def doc_to_line(filename, vocab):
    doc = load_doc(filename)
    tokens = clean_doc(doc)
    tokens = [w for w in tokens if w in vocab]
    return ' '.join(tokens)

# %%
def process_docs(directory, vocab, is_train):
    lines = list()
    for filename in listdir(directory):
        if is_train and filename.startswith('cv9'):
            continue
        if not is_train and filename.startswith(".cv9"):
            continue
        path = directory + '/' + filename
        line = doc_to_line(path, vocab)
        lines.append(line)
    return line

# %%
negative_lines = process_docs('datasets/review_polarity/txt_sentoken/neg', vocab)
save_list(negative_lines, 'datasets/negative.txt')
positive_lines = process_docs('datasets/review_polarity/txt_sentoken/pos', vocab)
save_list(negative_lines, 'datasets/positive.txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-06bcf69c0d4d> in <module>
# ----> 1 negative_lines = process_docs('datasets/review_polarity/txt_sentoken/neg', vocab)
#       2 save_list(negative_lines, 'datasets/negative.txt')
#       3 positive_lines = process_docs('datasets/review_polarity/txt_sentoken/pos', vocab)
#       4 save_list(negative_lines, 'datasets/positive.txt')
#
# TypeError: process_docs() missing 1 required positional argument: 'is_train'

# %%
def load_clean_dataset(vocab, is_train):
    neg = process_docs('datasets/review_polarity/txt_sentoken/neg', vocab, is_train)
    pos = process_docs('datasets/review_polarity/txt_sentoken/pos', vocab, is_train)
    docs = neg + pos
    labels = [0 for _ in range(len(neg))]+ [1 for _ in range(len(pos))]
    return docs, labels

# %%
vocab_filename = 'datasets/vocab.txt'
vocab = load_doc(vocab_filename)
vocab = vocab.split()
vocab = set(vocab)

# %%
docs, labels = load_clean_dataset(vocab)
print(len(docs), len(labels))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-3522cea55b3b> in <module>
# ----> 1 docs, labels = load_clean_dataset(vocab)
#       2 print(len(docs), len(labels))
#
# TypeError: load_clean_dataset() missing 1 required positional argument: 'is_train'

# %%
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
vocab_filename = 'datasets/vocab.txt'
vocab = load_doc(vocab_filename)
vocab = set(vocab.split())

# %%
train_docs, ytrain = load_clean_dataset(vocab, True)
test_docs, ytest = load_clean_dataset(vocab, False)

# %%
tokenizer = create_tokenizer(train_docs)

# %%
Xtrain = tokenizer.texts_to_matrix(train_docs, mode='freq')
Xtest = tokenizer.texts_to_matrix(test_docs, mode='freq')

# %%
print(Xtrain.shape, Xtest.shape)
# Out:
# (3062, 27) (5255, 27)

# %%
n_words = Xtest.shape[1]

# %%
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense

# %%
def define_model(n_words):
    model = Sequential()
    model.add(Dense(50, input_shape=(n_words,), activation='relu'))
    model.add(Dense(1, activation = 'sigmoid'))
    model.compile(loss= 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    model.summary()
    return model

# %%
model = define_model(n_words)
model.fit(Xtrain, ytrain, epochs=10, verbose=2)
# Out:
# Model: "sequential_124"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_246 (Dense)            (None, 50)                1400
# _________________________________________________________________
# dense_247 (Dense)            (None, 1)                 51
# =================================================================
# Total params: 1,451
# Trainable params: 1,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 0s - loss: 0.6823 - accuracy: 0.5810
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5859
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5859

# %%
loss, acc = model.evaluate(Xtest, ytest, verbose = 0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 65.366316

# %%
def prepare_data(train_docs, test_docs, mode):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(train_docs)
    Xtrain = tokenizer.texts_to_matrix(train_docs, mode= mode)
    Xtest = tokenizer.texts_to_matrix(test_docs, mode= mode)
    return Xtrain, Xtest

# %%
def evaluate_model(Xtrain, ytrain, Xtest, ytest):
    scores = list()
    n_repeats = 30
    n_words = Xtest.shape[1]
    for i in range(n_repeats):
        model = Sequential()
        model.add(Dense(50, input_shape=(n_words,), activation='relu'))
        model.add(Dense(1, activation = 'sigmoid'))
        model.compile(loss= 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
        model.fit(Xtrain, ytrain, epochs=10, verbose=2)
        loss, acc = model.evaluate(Xtest, ytest, verbose = 0)
        scores.append(acc)
        print('Test Accuracy: %s' % (i+1), acc)
    return scores

# %%
vocab_filename = 'datasets/vocab.txt'
vocab = load_doc(vocab_filename)
vocab = set(vocab.split())

# %%
train_docs, ytrain = load_clean_dataset(vocab, True)
test_docs, ytest = load_clean_dataset(vocab, False)

# %%
from pandas import DataFrame
modes = ['binary','count','tfidf','freq']
results = DataFrame()
for mode in modes:
    Xtrain, Xtest = prepare_data(train_docs, test_docs, mode)
    results[mode] = evaluate_model(Xtrain, ytrain, Xtest, ytest)
print(results.describe())
# Out:
# Epoch 1/10
#  - 0s - loss: 0.6826 - accuracy: 0.5800
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5807
# Test Accuracy: 1 0.653472900390625
# Epoch 1/10
#  - 0s - loss: 0.6816 - accuracy: 0.5826
# Epoch 2/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5823
# Test Accuracy: 2 0.653472900390625
# Epoch 1/10
#  - 0s - loss: 0.6840 - accuracy: 0.5663
# Epoch 2/10
#  - 0s - loss: 0.6793 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5859
# Test Accuracy: 3 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6830 - accuracy: 0.5745
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5826
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5807
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5856
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5856
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5856
# Test Accuracy: 4 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6845 - accuracy: 0.5728
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5865
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Test Accuracy: 5 0.6433872580528259
# Epoch 1/10
#  - 0s - loss: 0.6851 - accuracy: 0.5621
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Test Accuracy: 6 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6813 - accuracy: 0.5849
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6772 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Test Accuracy: 7 0.6506184339523315
# Epoch 1/10
#  - 0s - loss: 0.6847 - accuracy: 0.5741
# Epoch 2/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5830
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5803
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5813
# Test Accuracy: 8 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6846 - accuracy: 0.5794
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Test Accuracy: 9 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6862 - accuracy: 0.5617
# Epoch 2/10
#  - 0s - loss: 0.6793 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5846
# Test Accuracy: 10 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6842 - accuracy: 0.5777
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6771 - accuracy: 0.5826
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6767 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5856
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5862
# Test Accuracy: 11 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.6850 - accuracy: 0.5634
# Epoch 2/10
#  - 0s - loss: 0.6800 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5826
# Test Accuracy: 12 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6834 - accuracy: 0.5696
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6774 - accuracy: 0.5856
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6772 - accuracy: 0.5803
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5833
# Test Accuracy: 13 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6844 - accuracy: 0.5676
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5833
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5843
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5816
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Test Accuracy: 14 0.6540437936782837
# Epoch 1/10
#  - 0s - loss: 0.6901 - accuracy: 0.5349
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5852
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5852
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Test Accuracy: 15 0.6567078828811646
# Epoch 1/10
#  - 0s - loss: 0.6861 - accuracy: 0.5679
# Epoch 2/10
#  - 0s - loss: 0.6794 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5846
# Test Accuracy: 16 0.6441484093666077
# Epoch 1/10
#  - 0s - loss: 0.6847 - accuracy: 0.5732
# Epoch 2/10
#  - 0s - loss: 0.6799 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5836
# Test Accuracy: 17 0.6439581513404846
# Epoch 1/10
#  - 0s - loss: 0.6876 - accuracy: 0.5526
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5856
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5852
# Test Accuracy: 18 0.6485252380371094
# Epoch 1/10
#  - 0s - loss: 0.6826 - accuracy: 0.5810
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5852
# Epoch 3/10
#  - 0s - loss: 0.6779 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5833
# Epoch 5/10
#  - 0s - loss: 0.6771 - accuracy: 0.5856
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5862
# Epoch 9/10
#  - 0s - loss: 0.6772 - accuracy: 0.5856
# Epoch 10/10
#  - 0s - loss: 0.6765 - accuracy: 0.5849
# Test Accuracy: 19 0.6540437936782837
# Epoch 1/10
#  - 0s - loss: 0.6862 - accuracy: 0.5617
# Epoch 2/10
#  - 0s - loss: 0.6798 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5852
# Test Accuracy: 20 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6843 - accuracy: 0.5712
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5852
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5852
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5839
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5816
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5856
# Test Accuracy: 21 0.6508087515830994
# Epoch 1/10
#  - 0s - loss: 0.6820 - accuracy: 0.5830
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5826
# Test Accuracy: 22 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6877 - accuracy: 0.5503
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5810
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5843
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5846
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5856
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5862
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5843
# Test Accuracy: 23 0.6483349204063416
# Epoch 1/10
#  - 0s - loss: 0.6842 - accuracy: 0.5800
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5803
# Test Accuracy: 24 0.6460514068603516
# Epoch 1/10
#  - 0s - loss: 0.6888 - accuracy: 0.5474
# Epoch 2/10
#  - 0s - loss: 0.6785 - accuracy: 0.5843
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6766 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5823
# Test Accuracy: 25 0.6481446027755737
# Epoch 1/10
#  - 0s - loss: 0.6891 - accuracy: 0.5444
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6767 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6766 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5843
# Test Accuracy: 26 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6861 - accuracy: 0.5588
# Epoch 2/10
#  - 0s - loss: 0.6793 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5846
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5839
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5859
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5859
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5859
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5859
# Test Accuracy: 27 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6836 - accuracy: 0.5800
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5852
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5852
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5856
# Test Accuracy: 28 0.6563273072242737
# Epoch 1/10
#  - 0s - loss: 0.6884 - accuracy: 0.5480
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Test Accuracy: 29 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6838 - accuracy: 0.5738
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Test Accuracy: 30 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6931 - accuracy: 0.5235
# Epoch 2/10
#  - 0s - loss: 0.6806 - accuracy: 0.5843
# Epoch 3/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6765 - accuracy: 0.5816
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5826
# Test Accuracy: 1 0.6485252380371094
# Epoch 1/10
#  - 0s - loss: 0.6843 - accuracy: 0.5692
# Epoch 2/10
#  - 0s - loss: 0.6802 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6780 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Test Accuracy: 2 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6826 - accuracy: 0.5761
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5843
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5843
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5823
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5803
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6771 - accuracy: 0.5839
# Test Accuracy: 3 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6838 - accuracy: 0.5647
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5859
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5859
# Test Accuracy: 4 0.6538534760475159
# Epoch 1/10
#  - 0s - loss: 0.6900 - accuracy: 0.5421
# Epoch 2/10
#  - 0s - loss: 0.6804 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5846
# Test Accuracy: 5 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6869 - accuracy: 0.5552
# Epoch 2/10
#  - 0s - loss: 0.6794 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5807
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Test Accuracy: 6 0.6468125581741333
# Epoch 1/10
#  - 0s - loss: 0.6854 - accuracy: 0.5709
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5856
# Epoch 8/10
#  - 0s - loss: 0.6767 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5849
# Test Accuracy: 7 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6818 - accuracy: 0.5843
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5846
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5836
# Test Accuracy: 8 0.6483349204063416
# Epoch 1/10
#  - 0s - loss: 0.6840 - accuracy: 0.5741
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5856
# Test Accuracy: 9 0.6565176248550415
# Epoch 1/10
#  - 0s - loss: 0.6855 - accuracy: 0.5614
# Epoch 2/10
#  - 0s - loss: 0.6799 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5826
# Test Accuracy: 10 0.6563273072242737
# Epoch 1/10
#  - 0s - loss: 0.6852 - accuracy: 0.5581
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5826
# Test Accuracy: 11 0.653472900390625
# Epoch 1/10
#  - 0s - loss: 0.6832 - accuracy: 0.5774
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5839
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5839
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5836
# Test Accuracy: 12 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6823 - accuracy: 0.5784
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5839
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5843
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5833
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5820
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5826
# Test Accuracy: 13 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6843 - accuracy: 0.5781
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5846
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5846
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6772 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Test Accuracy: 14 0.653472900390625
# Epoch 1/10
#  - 0s - loss: 0.6823 - accuracy: 0.5816
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Test Accuracy: 15 0.653472900390625
# Epoch 1/10
#  - 0s - loss: 0.6907 - accuracy: 0.5300
# Epoch 2/10
#  - 0s - loss: 0.6793 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5839
# Test Accuracy: 16 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6837 - accuracy: 0.5767
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Test Accuracy: 17 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6809 - accuracy: 0.5797
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5813
# Test Accuracy: 18 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6838 - accuracy: 0.5666
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5833
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6766 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5823
# Test Accuracy: 19 0.6506184339523315
# Epoch 1/10
#  - 0s - loss: 0.6855 - accuracy: 0.5634
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5846
# Test Accuracy: 20 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6854 - accuracy: 0.5572
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5833
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5859
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5862
# Test Accuracy: 21 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6832 - accuracy: 0.5771
# Epoch 2/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5830
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5843
# Test Accuracy: 22 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6850 - accuracy: 0.5624
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5852
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5836
# Test Accuracy: 23 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6852 - accuracy: 0.5578
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Test Accuracy: 24 0.6559467315673828
# Epoch 1/10
#  - 0s - loss: 0.6838 - accuracy: 0.5673
# Epoch 2/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5859
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6766 - accuracy: 0.5820
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5843
# Test Accuracy: 25 0.6439581513404846
# Epoch 1/10
#  - 0s - loss: 0.6841 - accuracy: 0.5656
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6769 - accuracy: 0.5830
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5830
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Test Accuracy: 26 0.6563273072242737
# Epoch 1/10
#  - 0s - loss: 0.6860 - accuracy: 0.5683
# Epoch 2/10
#  - 0s - loss: 0.6808 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6793 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Test Accuracy: 27 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6868 - accuracy: 0.5634
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5852
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5852
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5830
# Test Accuracy: 28 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6888 - accuracy: 0.5402
# Epoch 2/10
#  - 0s - loss: 0.6807 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6792 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Test Accuracy: 29 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6835 - accuracy: 0.5774
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5820
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Test Accuracy: 30 0.6538534760475159
# Epoch 1/10
#  - 0s - loss: 0.6921 - accuracy: 0.5568
# Epoch 2/10
#  - 0s - loss: 0.6817 - accuracy: 0.5816
# Epoch 3/10
#  - 0s - loss: 0.6789 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6789 - accuracy: 0.5800
# Epoch 5/10
#  - 0s - loss: 0.6778 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6781 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6774 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6780 - accuracy: 0.5816
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5856
# Test Accuracy: 1 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6879 - accuracy: 0.5787
# Epoch 2/10
#  - 0s - loss: 0.6807 - accuracy: 0.5856
# Epoch 3/10
#  - 0s - loss: 0.6794 - accuracy: 0.5836
# Epoch 4/10
#  - 0s - loss: 0.6788 - accuracy: 0.5833
# Epoch 5/10
#  - 0s - loss: 0.6781 - accuracy: 0.5820
# Epoch 6/10
#  - 0s - loss: 0.6780 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6782 - accuracy: 0.5839
# Epoch 8/10
#  - 0s - loss: 0.6785 - accuracy: 0.5862
# Epoch 9/10
#  - 0s - loss: 0.6777 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6774 - accuracy: 0.5852
# Test Accuracy: 2 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6908 - accuracy: 0.5565
# Epoch 2/10
#  - 0s - loss: 0.6814 - accuracy: 0.5820
# Epoch 3/10
#  - 0s - loss: 0.6792 - accuracy: 0.5826
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5862
# Epoch 5/10
#  - 0s - loss: 0.6790 - accuracy: 0.5813
# Epoch 6/10
#  - 0s - loss: 0.6782 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6778 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5826
# Epoch 10/10
#  - 0s - loss: 0.6776 - accuracy: 0.5823
# Test Accuracy: 3 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6906 - accuracy: 0.5496
# Epoch 2/10
#  - 0s - loss: 0.6818 - accuracy: 0.5718
# Epoch 3/10
#  - 0s - loss: 0.6797 - accuracy: 0.5823
# Epoch 4/10
#  - 0s - loss: 0.6789 - accuracy: 0.5846
# Epoch 5/10
#  - 0s - loss: 0.6791 - accuracy: 0.5830
# Epoch 6/10
#  - 0s - loss: 0.6788 - accuracy: 0.5820
# Epoch 7/10
#  - 0s - loss: 0.6789 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6789 - accuracy: 0.5820
# Epoch 9/10
#  - 0s - loss: 0.6786 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Test Accuracy: 4 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6905 - accuracy: 0.5745
# Epoch 2/10
#  - 0s - loss: 0.6816 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6796 - accuracy: 0.5830
# Epoch 4/10
#  - 0s - loss: 0.6788 - accuracy: 0.5826
# Epoch 5/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6781 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6783 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6788 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6782 - accuracy: 0.5862
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5852
# Test Accuracy: 5 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.6870 - accuracy: 0.5660
# Epoch 2/10
#  - 0s - loss: 0.6806 - accuracy: 0.5813
# Epoch 3/10
#  - 0s - loss: 0.6796 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6787 - accuracy: 0.5852
# Epoch 5/10
#  - 0s - loss: 0.6785 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6784 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6781 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6779 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6782 - accuracy: 0.5813
# Epoch 10/10
#  - 0s - loss: 0.6781 - accuracy: 0.5820
# Test Accuracy: 6 0.6538534760475159
# Epoch 1/10
#  - 0s - loss: 0.6979 - accuracy: 0.5314
# Epoch 2/10
#  - 0s - loss: 0.6809 - accuracy: 0.5823
# Epoch 3/10
#  - 0s - loss: 0.6798 - accuracy: 0.5803
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5839
# Epoch 5/10
#  - 0s - loss: 0.6783 - accuracy: 0.5836
# Epoch 6/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6782 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6782 - accuracy: 0.5820
# Epoch 10/10
#  - 0s - loss: 0.6781 - accuracy: 0.5820
# Test Accuracy: 7 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.7020 - accuracy: 0.5297
# Epoch 2/10
#  - 0s - loss: 0.6814 - accuracy: 0.5807
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5787
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5856
# Epoch 5/10
#  - 0s - loss: 0.6782 - accuracy: 0.5826
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5800
# Epoch 7/10
#  - 0s - loss: 0.6775 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6782 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6776 - accuracy: 0.5869
# Epoch 10/10
#  - 0s - loss: 0.6776 - accuracy: 0.5820
# Test Accuracy: 8 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.7067 - accuracy: 0.5180
# Epoch 2/10
#  - 0s - loss: 0.6798 - accuracy: 0.5823
# Epoch 3/10
#  - 0s - loss: 0.6787 - accuracy: 0.5839
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5820
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5859
# Epoch 6/10
#  - 0s - loss: 0.6784 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6776 - accuracy: 0.5833
# Epoch 8/10
#  - 0s - loss: 0.6782 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6777 - accuracy: 0.5820
# Epoch 10/10
#  - 0s - loss: 0.6775 - accuracy: 0.5823
# Test Accuracy: 9 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.6924 - accuracy: 0.5669
# Epoch 2/10
#  - 0s - loss: 0.6810 - accuracy: 0.5820
# Epoch 3/10
#  - 0s - loss: 0.6793 - accuracy: 0.5846
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6780 - accuracy: 0.5833
# Epoch 6/10
#  - 0s - loss: 0.6778 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6780 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6777 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6780 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5823
# Test Accuracy: 10 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.6879 - accuracy: 0.5647
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5826
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5826
# Epoch 4/10
#  - 0s - loss: 0.6783 - accuracy: 0.5794
# Epoch 5/10
#  - 0s - loss: 0.6782 - accuracy: 0.5856
# Epoch 6/10
#  - 0s - loss: 0.6783 - accuracy: 0.5856
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5813
# Epoch 8/10
#  - 0s - loss: 0.6778 - accuracy: 0.5826
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6778 - accuracy: 0.5843
# Test Accuracy: 11 0.6483349204063416
# Epoch 1/10
#  - 0s - loss: 0.6890 - accuracy: 0.5686
# Epoch 2/10
#  - 0s - loss: 0.6811 - accuracy: 0.5839
# Epoch 3/10
#  - 0s - loss: 0.6794 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6789 - accuracy: 0.5826
# Epoch 5/10
#  - 0s - loss: 0.6785 - accuracy: 0.5830
# Epoch 6/10
#  - 0s - loss: 0.6780 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6780 - accuracy: 0.5830
# Epoch 8/10
#  - 0s - loss: 0.6781 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6777 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6776 - accuracy: 0.5833
# Test Accuracy: 12 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.6946 - accuracy: 0.5474
# Epoch 2/10
#  - 0s - loss: 0.6819 - accuracy: 0.5810
# Epoch 3/10
#  - 0s - loss: 0.6795 - accuracy: 0.5836
# Epoch 4/10
#  - 0s - loss: 0.6788 - accuracy: 0.5830
# Epoch 5/10
#  - 0s - loss: 0.6782 - accuracy: 0.5830
# Epoch 6/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6777 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5781
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5856
# Test Accuracy: 13 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.7031 - accuracy: 0.5398
# Epoch 2/10
#  - 0s - loss: 0.6824 - accuracy: 0.5836
# Epoch 3/10
#  - 0s - loss: 0.6802 - accuracy: 0.5856
# Epoch 4/10
#  - 0s - loss: 0.6793 - accuracy: 0.5833
# Epoch 5/10
#  - 0s - loss: 0.6790 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6783 - accuracy: 0.5859
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5859
# Epoch 8/10
#  - 0s - loss: 0.6776 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6781 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6783 - accuracy: 0.5833
# Test Accuracy: 14 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6884 - accuracy: 0.5588
# Epoch 2/10
#  - 0s - loss: 0.6803 - accuracy: 0.5820
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5826
# Epoch 4/10
#  - 0s - loss: 0.6791 - accuracy: 0.5797
# Epoch 5/10
#  - 0s - loss: 0.6787 - accuracy: 0.5872
# Epoch 6/10
#  - 0s - loss: 0.6785 - accuracy: 0.5865
# Epoch 7/10
#  - 0s - loss: 0.6787 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6778 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6787 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6782 - accuracy: 0.5852
# Test Accuracy: 15 0.6388201713562012
# Epoch 1/10
#  - 0s - loss: 0.6997 - accuracy: 0.5431
# Epoch 2/10
#  - 0s - loss: 0.6822 - accuracy: 0.5735
# Epoch 3/10
#  - 0s - loss: 0.6796 - accuracy: 0.5797
# Epoch 4/10
#  - 0s - loss: 0.6790 - accuracy: 0.5807
# Epoch 5/10
#  - 0s - loss: 0.6781 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6784 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5872
# Epoch 8/10
#  - 0s - loss: 0.6782 - accuracy: 0.5784
# Epoch 9/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6775 - accuracy: 0.5826
# Test Accuracy: 16 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.7077 - accuracy: 0.5222
# Epoch 2/10
#  - 0s - loss: 0.6819 - accuracy: 0.5833
# Epoch 3/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6783 - accuracy: 0.5833
# Epoch 5/10
#  - 0s - loss: 0.6782 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5820
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5872
# Epoch 8/10
#  - 0s - loss: 0.6777 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6781 - accuracy: 0.5869
# Epoch 10/10
#  - 0s - loss: 0.6776 - accuracy: 0.5820
# Test Accuracy: 17 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.6907 - accuracy: 0.5699
# Epoch 2/10
#  - 0s - loss: 0.6814 - accuracy: 0.5836
# Epoch 3/10
#  - 0s - loss: 0.6792 - accuracy: 0.5846
# Epoch 4/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6781 - accuracy: 0.5859
# Epoch 6/10
#  - 0s - loss: 0.6777 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6777 - accuracy: 0.5836
# Epoch 8/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6777 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6777 - accuracy: 0.5836
# Test Accuracy: 18 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.7063 - accuracy: 0.5271
# Epoch 2/10
#  - 0s - loss: 0.6817 - accuracy: 0.5813
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5839
# Epoch 4/10
#  - 0s - loss: 0.6788 - accuracy: 0.5816
# Epoch 5/10
#  - 0s - loss: 0.6786 - accuracy: 0.5833
# Epoch 6/10
#  - 0s - loss: 0.6781 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6776 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6787 - accuracy: 0.5833
# Epoch 9/10
#  - 0s - loss: 0.6784 - accuracy: 0.5820
# Epoch 10/10
#  - 0s - loss: 0.6782 - accuracy: 0.5816
# Test Accuracy: 19 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.7027 - accuracy: 0.5327
# Epoch 2/10
#  - 0s - loss: 0.6815 - accuracy: 0.5797
# Epoch 3/10
#  - 0s - loss: 0.6796 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5843
# Epoch 5/10
#  - 0s - loss: 0.6783 - accuracy: 0.5839
# Epoch 6/10
#  - 0s - loss: 0.6785 - accuracy: 0.5862
# Epoch 7/10
#  - 0s - loss: 0.6784 - accuracy: 0.5830
# Epoch 8/10
#  - 0s - loss: 0.6781 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6780 - accuracy: 0.5839
# Epoch 10/10
#  - 0s - loss: 0.6781 - accuracy: 0.5807
# Test Accuracy: 20 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.7080 - accuracy: 0.5183
# Epoch 2/10
#  - 0s - loss: 0.6808 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5813
# Epoch 4/10
#  - 0s - loss: 0.6789 - accuracy: 0.5813
# Epoch 5/10
#  - 0s - loss: 0.6784 - accuracy: 0.5862
# Epoch 6/10
#  - 0s - loss: 0.6783 - accuracy: 0.5820
# Epoch 7/10
#  - 0s - loss: 0.6777 - accuracy: 0.5816
# Epoch 8/10
#  - 0s - loss: 0.6774 - accuracy: 0.5856
# Epoch 9/10
#  - 0s - loss: 0.6776 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6776 - accuracy: 0.5846
# Test Accuracy: 21 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.7032 - accuracy: 0.5356
# Epoch 2/10
#  - 0s - loss: 0.6819 - accuracy: 0.5797
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6779 - accuracy: 0.5856
# Epoch 7/10
#  - 0s - loss: 0.6779 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6783 - accuracy: 0.5856
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Test Accuracy: 22 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6866 - accuracy: 0.5745
# Epoch 2/10
#  - 0s - loss: 0.6811 - accuracy: 0.5820
# Epoch 3/10
#  - 0s - loss: 0.6798 - accuracy: 0.5856
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5807
# Epoch 5/10
#  - 0s - loss: 0.6787 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6779 - accuracy: 0.5856
# Epoch 7/10
#  - 0s - loss: 0.6787 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6781 - accuracy: 0.5797
# Epoch 9/10
#  - 0s - loss: 0.6779 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5856
# Test Accuracy: 23 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.6865 - accuracy: 0.5676
# Epoch 2/10
#  - 0s - loss: 0.6802 - accuracy: 0.5816
# Epoch 3/10
#  - 0s - loss: 0.6789 - accuracy: 0.5830
# Epoch 4/10
#  - 0s - loss: 0.6789 - accuracy: 0.5813
# Epoch 5/10
#  - 0s - loss: 0.6783 - accuracy: 0.5859
# Epoch 6/10
#  - 0s - loss: 0.6784 - accuracy: 0.5816
# Epoch 7/10
#  - 0s - loss: 0.6784 - accuracy: 0.5839
# Epoch 8/10
#  - 0s - loss: 0.6784 - accuracy: 0.5859
# Epoch 9/10
#  - 0s - loss: 0.6783 - accuracy: 0.5859
# Epoch 10/10
#  - 0s - loss: 0.6777 - accuracy: 0.5872
# Test Accuracy: 24 0.639200747013092
# Epoch 1/10
#  - 0s - loss: 0.6929 - accuracy: 0.5477
# Epoch 2/10
#  - 0s - loss: 0.6814 - accuracy: 0.5836
# Epoch 3/10
#  - 0s - loss: 0.6790 - accuracy: 0.5862
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5839
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5846
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6778 - accuracy: 0.5865
# Epoch 8/10
#  - 0s - loss: 0.6783 - accuracy: 0.5826
# Epoch 9/10
#  - 0s - loss: 0.6775 - accuracy: 0.5830
# Epoch 10/10
#  - 0s - loss: 0.6780 - accuracy: 0.5862
# Test Accuracy: 25 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.6915 - accuracy: 0.5588
# Epoch 2/10
#  - 0s - loss: 0.6808 - accuracy: 0.5823
# Epoch 3/10
#  - 0s - loss: 0.6793 - accuracy: 0.5833
# Epoch 4/10
#  - 0s - loss: 0.6786 - accuracy: 0.5843
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5859
# Epoch 6/10
#  - 0s - loss: 0.6783 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6780 - accuracy: 0.5816
# Epoch 8/10
#  - 0s - loss: 0.6779 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6778 - accuracy: 0.5794
# Epoch 10/10
#  - 0s - loss: 0.6781 - accuracy: 0.5843
# Test Accuracy: 26 0.6542340517044067
# Epoch 1/10
#  - 0s - loss: 0.6974 - accuracy: 0.5532
# Epoch 2/10
#  - 0s - loss: 0.6820 - accuracy: 0.5813
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5820
# Epoch 4/10
#  - 0s - loss: 0.6788 - accuracy: 0.5865
# Epoch 5/10
#  - 0s - loss: 0.6789 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6790 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6784 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6782 - accuracy: 0.5862
# Epoch 9/10
#  - 0s - loss: 0.6786 - accuracy: 0.5882
# Epoch 10/10
#  - 0s - loss: 0.6783 - accuracy: 0.5836
# Test Accuracy: 27 0.6490960717201233
# Epoch 1/10
#  - 0s - loss: 0.7029 - accuracy: 0.5307
# Epoch 2/10
#  - 0s - loss: 0.6807 - accuracy: 0.5839
# Epoch 3/10
#  - 0s - loss: 0.6787 - accuracy: 0.5846
# Epoch 4/10
#  - 0s - loss: 0.6786 - accuracy: 0.5813
# Epoch 5/10
#  - 0s - loss: 0.6780 - accuracy: 0.5830
# Epoch 6/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6774 - accuracy: 0.5836
# Epoch 8/10
# ...
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Test Accuracy: 2 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6871 - accuracy: 0.5572
# Epoch 2/10
#  - 0s - loss: 0.6786 - accuracy: 0.5843
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5839
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5856
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Test Accuracy: 3 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6830 - accuracy: 0.5803
# Epoch 2/10
#  - 0s - loss: 0.6800 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6788 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6771 - accuracy: 0.5826
# Test Accuracy: 4 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6882 - accuracy: 0.5487
# Epoch 2/10
#  - 0s - loss: 0.6799 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5839
# Test Accuracy: 5 0.6483349204063416
# Epoch 1/10
#  - 0s - loss: 0.6840 - accuracy: 0.5689
# Epoch 2/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5843
# Test Accuracy: 6 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6831 - accuracy: 0.5738
# Epoch 2/10
#  - 0s - loss: 0.6792 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5790
# Epoch 8/10
#  - 0s - loss: 0.6767 - accuracy: 0.5826
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5794
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5813
# Test Accuracy: 7 0.6388201713562012
# Epoch 1/10
#  - 0s - loss: 0.6867 - accuracy: 0.5581
# Epoch 2/10
#  - 0s - loss: 0.6801 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6792 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5843
# Epoch 8/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5803
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Test Accuracy: 8 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6842 - accuracy: 0.5702
# Epoch 2/10
#  - 0s - loss: 0.6792 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5830
# Test Accuracy: 9 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6824 - accuracy: 0.5807
# Epoch 2/10
#  - 0s - loss: 0.6790 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Test Accuracy: 10 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6828 - accuracy: 0.5800
# Epoch 2/10
#  - 0s - loss: 0.6794 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5839
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5836
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5836
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6775 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5833
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5830
# Test Accuracy: 11 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6883 - accuracy: 0.5588
# Epoch 2/10
#  - 0s - loss: 0.6799 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5833
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5830
# Test Accuracy: 12 0.6433872580528259
# Epoch 1/10
#  - 0s - loss: 0.6824 - accuracy: 0.5797
# Epoch 2/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5830
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5810
# Test Accuracy: 13 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6832 - accuracy: 0.5823
# Epoch 2/10
#  - 0s - loss: 0.6802 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6791 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6779 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5846
# Epoch 9/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6775 - accuracy: 0.5830
# Test Accuracy: 14 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6858 - accuracy: 0.5621
# Epoch 2/10
#  - 0s - loss: 0.6791 - accuracy: 0.5843
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5852
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5836
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5833
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5813
# Epoch 7/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5823
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5800
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5856
# Test Accuracy: 15 0.6506184339523315
# Epoch 1/10
#  - 0s - loss: 0.6824 - accuracy: 0.5790
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5833
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5846
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5843
# Test Accuracy: 16 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6836 - accuracy: 0.5745
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5852
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6767 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5856
# Test Accuracy: 17 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6842 - accuracy: 0.5816
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6787 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846
# Test Accuracy: 18 0.6559467315673828
# Epoch 1/10
#  - 0s - loss: 0.6829 - accuracy: 0.5843
# Epoch 2/10
#  - 0s - loss: 0.6800 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6788 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6772 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5852
# Test Accuracy: 19 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6817 - accuracy: 0.5839
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5816
# Test Accuracy: 20 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6840 - accuracy: 0.5738
# Epoch 2/10
#  - 0s - loss: 0.6803 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6789 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6784 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5800
# Test Accuracy: 21 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6852 - accuracy: 0.5634
# Epoch 2/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6777 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5839
# Epoch 7/10
#  - 0s - loss: 0.6769 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5836
# Test Accuracy: 22 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6878 - accuracy: 0.5415
# Epoch 2/10
#  - 0s - loss: 0.6792 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5830
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5826
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6771 - accuracy: 0.5843
# Epoch 10/10
#  - 0s - loss: 0.6767 - accuracy: 0.5856
# Test Accuracy: 23 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6876 - accuracy: 0.5509
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5843
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6776 - accuracy: 0.5833
# Epoch 5/10
#  - 0s - loss: 0.6777 - accuracy: 0.5843
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6770 - accuracy: 0.5823
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5843
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5839
# Test Accuracy: 24 0.6511893272399902
# Epoch 1/10
#  - 0s - loss: 0.6856 - accuracy: 0.5630
# Epoch 2/10
#  - 0s - loss: 0.6796 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6781 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5846
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5846
# Epoch 10/10
#  - 0s - loss: 0.6768 - accuracy: 0.5846
# Test Accuracy: 25 0.6561369895935059
# Epoch 1/10
#  - 0s - loss: 0.6828 - accuracy: 0.5781
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6775 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6771 - accuracy: 0.5836
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5830
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5836
# Epoch 9/10
#  - 0s - loss: 0.6773 - accuracy: 0.5823
# Epoch 10/10
#  - 0s - loss: 0.6770 - accuracy: 0.5879
# Test Accuracy: 26 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6830 - accuracy: 0.5728
# Epoch 2/10
#  - 0s - loss: 0.6797 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5833
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6768 - accuracy: 0.5836
# Epoch 8/10
#  - 0s - loss: 0.6768 - accuracy: 0.5852
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5826
# Epoch 10/10
#  - 0s - loss: 0.6764 - accuracy: 0.5859
# Test Accuracy: 27 0.653663158416748
# Epoch 1/10
#  - 0s - loss: 0.6855 - accuracy: 0.5604
# Epoch 2/10
#  - 0s - loss: 0.6788 - accuracy: 0.5836
# Epoch 3/10
#  - 0s - loss: 0.6780 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6770 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6770 - accuracy: 0.5843
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6770 - accuracy: 0.5830
# Epoch 9/10
#  - 0s - loss: 0.6767 - accuracy: 0.5836
# Epoch 10/10
#  - 0s - loss: 0.6766 - accuracy: 0.5869
# Test Accuracy: 28 0.655756413936615
# Epoch 1/10
#  - 0s - loss: 0.6870 - accuracy: 0.5523
# Epoch 2/10
#  - 0s - loss: 0.6795 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6786 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6773 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5836
# Epoch 8/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5810
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Test Accuracy: 29 0.6532825827598572
# Epoch 1/10
#  - 0s - loss: 0.6923 - accuracy: 0.5238
# Epoch 2/10
#  - 0s - loss: 0.6813 - accuracy: 0.5849
# Epoch 3/10
#  - 0s - loss: 0.6794 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6785 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6782 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6776 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 9/10
#  - 0s - loss: 0.6768 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Test Accuracy: 30 0.6559467315673828
#           binary      count      tfidf       freq
# count  30.000000  30.000000  30.000000  30.000000
# mean    0.652445   0.653479   0.646445   0.653473
# std     0.003988   0.003031   0.005957   0.003897
# min     0.643387   0.643958   0.638820   0.638820
# 25%     0.650666   0.653330   0.639201   0.653283
# 50%     0.653663   0.653663   0.649096   0.654710
# 75%     0.655756   0.655756   0.649096   0.655756
# max     0.656708   0.656518   0.654234   0.656137

# %%
def predict_sentiment(review, vocab, tokenizer, model):
    tokens = clean_doc(review)
    tokens = [w for w in tokens if w in vocab]
    line = ' '.join(tokens)
    encoded = tokenizer.texts_to_matrix([line], mode='binary')
    yhat = model.predict(encoded, verbose = 0)
    percent_pos = yhat[0,0]
    if round(percent_pos) == 0:
        return (1-percent_pos), 'NEGATIVE'
    return percent_pos, 'POSITIVE'

# %%
model = define_model(n_words)
model.fit(Xtrain, ytrain, epochs= 10, verbose = 2)
# Out:
# Model: "sequential_245"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_488 (Dense)            (None, 50)                1400
# _________________________________________________________________
# dense_489 (Dense)            (None, 1)                 51
# =================================================================
# Total params: 1,451
# Trainable params: 1,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 0s - loss: 0.6857 - accuracy: 0.5591
# Epoch 2/10
#  - 0s - loss: 0.6789 - accuracy: 0.5846
# Epoch 3/10
#  - 0s - loss: 0.6783 - accuracy: 0.5849
# Epoch 4/10
#  - 0s - loss: 0.6778 - accuracy: 0.5849
# Epoch 5/10
#  - 0s - loss: 0.6774 - accuracy: 0.5849
# Epoch 6/10
#  - 0s - loss: 0.6772 - accuracy: 0.5849
# Epoch 7/10
#  - 0s - loss: 0.6771 - accuracy: 0.5849
# Epoch 8/10
#  - 0s - loss: 0.6772 - accuracy: 0.5839
# Epoch 9/10
#  - 0s - loss: 0.6769 - accuracy: 0.5849
# Epoch 10/10
#  - 0s - loss: 0.6769 - accuracy: 0.5846

# %%
text = 'Best moview ever! It was great, I recoomend it.'
percent, sentiment = predict_sentiment(text, vocab, tokenizer, model)

# %%
print('Review: [%s]\nSentiment: %s (%.3f%%)' % (text, sentiment, percent*100))
# Out:
# Review: [Best moview ever! It was great, I recoomend it.]
# Sentiment: POSITIVE (57.154%)
